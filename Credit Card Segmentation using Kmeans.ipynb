# %% [markdown]
# # Credit Card Segmentation using Kmeans

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
credit = pd.read_csv('C:/Users/ok/Desktop/customer segmentation.csv')
credit.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
credit.shape
# Out:
# (8950, 18)

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
credit.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
credit.MINIMUM_PAYMENTS.fillna(value=df1.MINIMUM_PAYMENTS.mean(),inplace=True)

# %%
credit.CREDIT_LIMIT.fillna(value=df1.CREDIT_LIMIT.mean(),inplace=True)

# %%
credit.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# dtype: bool

# %%
credit.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
credit['monthly_avg_purchases']=credit.PURCHASES /credit.TENURE

# %%
credit['monthly_cash_advance']=credit.CASH_ADVANCE /credit.TENURE

# %%
credit[(credit.ONEOFF_PURCHASES == 0) & (credit.INSTALLMENTS_PURCHASES == 0)].shape[0]
# Out:
# 2042

# %%
credit[(credit.ONEOFF_PURCHASES > 0) & (credit.INSTALLMENTS_PURCHASES > 0)].shape[0]
# Out:
# 2774

# %%
credit[(credit.ONEOFF_PURCHASES > 0) & (credit.INSTALLMENTS_PURCHASES == 0)].shape[0]
# Out:
# 1874

# %%
credit[(credit.ONEOFF_PURCHASES == 0) & (credit.INSTALLMENTS_PURCHASES > 0)].shape[0]
# Out:
# 2260

# %%
def func(credit):
    if (credit.ONEOFF_PURCHASES == 0) & (credit.INSTALLMENTS_PURCHASES == 0):
        return 'none_one_ins'
    elif (credit.ONEOFF_PURCHASES > 0) & (credit.INSTALLMENTS_PURCHASES > 0):
        return 'both_one_ins'
    elif (credit.ONEOFF_PURCHASES > 0) & (credit.INSTALLMENTS_PURCHASES == 0):
        return 'one_off'
    else:
        return 'installment_withou_one'

# %%
credit['purchase_type']=credit.apply(func,axis=1)

# %%
credit
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                       0.000000                          0.083333  ...
# 1                       0.000000                          0.000000  ...
# 2                       1.000000                          0.000000  ...
# 3                       0.083333                          0.000000  ...
# 4                       0.083333                          0.000000  ...
# ...                          ...                               ...  ...
# 8945                    0.000000                          0.833333  ...
# 8946                    0.000000                          0.833333  ...
# 8947                    0.000000                          0.666667  ...
# 8948                    0.000000                          0.000000  ...
# 8949                    0.666667                          0.000000  ...
#
#       CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  \
# 0                    0              2        1000.0   201.802084
# 1                    4              0        7000.0  4103.032597
# 2                    0             12        7500.0   622.066742
# 3                    1              1        7500.0     0.000000
# 4                    0              1        1200.0   678.334763
# ...                ...            ...           ...          ...
# 8945                 0              6        1000.0   325.594462
# 8946                 0              6        1000.0   275.861322
# 8947                 0              5        1000.0    81.270775
# 8948                 2              0         500.0    52.549959
# 8949                 2             23        1200.0    63.165404
#
#       MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  monthly_avg_purchases  \
# 0           139.509787          0.000000      12               7.950000
# 1          1072.340217          0.222222      12               0.000000
# 2           627.284787          0.000000      12              64.430833
# 3           864.206542          0.000000      12             124.916667
# 4           244.791237          0.000000      12               1.333333
# ...                ...               ...     ...                    ...
# 8945         48.886365          0.500000       6              48.520000
# 8946        864.206542          0.000000       6              50.000000
# 8947         82.418369          0.250000       6              24.066667
# 8948         55.755628          0.250000       6               0.000000
# 8949         88.288956          0.000000       6             182.208333
#
#       monthly_cash_advance           purchase_type
# 0                 0.000000  installment_withou_one
# 1               536.912124            none_one_ins
# 2                 0.000000                 one_off
# 3                17.149001                 one_off
# 4                 0.000000                 one_off
# ...                    ...                     ...
# 8945              0.000000  installment_withou_one
# 8946              0.000000  installment_withou_one
# 8947              0.000000  installment_withou_one
# 8948              6.093130            none_one_ins
# 8949             21.173335                 one_off
#
# [8950 rows x 21 columns]

# %%
credit=pd.concat([credit,pd.get_dummies(credit['purchase_type'])],axis=1)

# %%
credit
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                       0.000000                          0.083333  ...
# 1                       0.000000                          0.000000  ...
# 2                       1.000000                          0.000000  ...
# 3                       0.083333                          0.000000  ...
# 4                       0.083333                          0.000000  ...
# ...                          ...                               ...  ...
# 8945                    0.000000                          0.833333  ...
# 8946                    0.000000                          0.833333  ...
# 8947                    0.000000                          0.666667  ...
# 8948                    0.000000                          0.000000  ...
# 8949                    0.666667                          0.000000  ...
#
#       MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  monthly_avg_purchases  \
# 0           139.509787          0.000000      12               7.950000
# 1          1072.340217          0.222222      12               0.000000
# 2           627.284787          0.000000      12              64.430833
# 3           864.206542          0.000000      12             124.916667
# 4           244.791237          0.000000      12               1.333333
# ...                ...               ...     ...                    ...
# 8945         48.886365          0.500000       6              48.520000
# 8946        864.206542          0.000000       6              50.000000
# 8947         82.418369          0.250000       6              24.066667
# 8948         55.755628          0.250000       6               0.000000
# 8949         88.288956          0.000000       6             182.208333
#
#       monthly_cash_advance           purchase_type  both_one_ins  \
# 0                 0.000000  installment_withou_one             0
# 1               536.912124            none_one_ins             0
# 2                 0.000000                 one_off             0
# 3                17.149001                 one_off             0
# 4                 0.000000                 one_off             0
# ...                    ...                     ...           ...
# 8945              0.000000  installment_withou_one             0
# 8946              0.000000  installment_withou_one             0
# 8947              0.000000  installment_withou_one             0
# 8948              6.093130            none_one_ins             0
# 8949             21.173335                 one_off             0
#
#       installment_withou_one  none_one_ins  one_off
# 0                          1             0        0
# 1                          0             1        0
# 2                          0             0        1
# 3                          0             0        1
# 4                          0             0        1
# ...                      ...           ...      ...
# 8945                       1             0        0
# 8946                       1             0        0
# 8947                       1             0        0
# 8948                       0             1        0
# 8949                       0             0        1
#
# [8950 rows x 25 columns]

# %%
credit.drop(['purchase_type','CUST_ID'],axis=1,inplace=True)

# %%
credit['limit_usage_ratatio']=credit.BALANCE /credit.CREDIT_LIMIT

# %%
credit['min_payment_ratio']= credit.PAYMENTS/credit.MINIMUM_PAYMENTS

# %%
credit
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE  \
# 0                   0.000000  ...          0.000000      12
# 1                   0.250000  ...          0.222222      12
# 2                   0.000000  ...          0.000000      12
# 3                   0.083333  ...          0.000000      12
# 4                   0.000000  ...          0.000000      12
# ...                      ...  ...               ...     ...
# 8945                0.000000  ...          0.500000       6
# 8946                0.000000  ...          0.000000       6
# 8947                0.000000  ...          0.250000       6
# 8948                0.166667  ...          0.250000       6
# 8949                0.333333  ...          0.000000       6
#
#       monthly_avg_purchases  monthly_cash_advance  both_one_ins  \
# 0                  7.950000              0.000000             0
# 1                  0.000000            536.912124             0
# 2                 64.430833              0.000000             0
# 3                124.916667             17.149001             0
# 4                  1.333333              0.000000             0
# ...                     ...                   ...           ...
# 8945              48.520000              0.000000             0
# 8946              50.000000              0.000000             0
# 8947              24.066667              0.000000             0
# 8948               0.000000              6.093130             0
# 8949             182.208333             21.173335             0
#
#       installment_withou_one  none_one_ins  one_off  limit_usage_ratatio  \
# 0                          1             0        0             0.040901
# 1                          0             1        0             0.457495
# 2                          0             0        1             0.332687
# 3                          0             0        1             0.222223
# 4                          0             0        1             0.681429
# ...                      ...           ...      ...                  ...
# 8945                       1             0        0             0.028494
# 8946                       1             0        0             0.019183
# 8947                       1             0        0             0.023399
# 8948                       0             1        0             0.026915
# 8949                       0             0        1             0.310590
#
#       min_payment_ratio
# 0              1.446508
# 1              3.826241
# 2              0.991682
# 3              0.000000
# 4              2.771075
# ...                 ...
# 8945           6.660231
# 8946           0.319208
# 8947           0.986076
# 8948           0.942505
# 8949           0.715439
#
# [8950 rows x 25 columns]

# %%
cr_log=credit[credit.columns.difference(['both_one_ins','installment_withou_one','none_one_ins','one_off'])].applymap(lambda x : np.log(x +1)).copy()

# %%
cr_log
# Out:
#        BALANCE  BALANCE_FREQUENCY  CASH_ADVANCE  CASH_ADVANCE_FREQUENCY  \
# 0     3.735304           0.597837      0.000000                0.000000
# 1     8.071989           0.646627      8.770896                0.223144
# 2     7.822504           0.693147      0.000000                0.000000
# 3     7.419183           0.492477      5.331694                0.080042
# 4     6.707735           0.693147      0.000000                0.000000
# ...        ...                ...           ...                     ...
# 8945  3.384170           0.693147      0.000000                0.000000
# 8946  3.004851           0.693147      0.000000                0.000000
# 8947  3.194529           0.606136      0.000000                0.000000
# 8948  2.671218           0.606136      3.625907                0.154151
# 8949  5.923475           0.510826      4.852343                0.287682
#
#       CASH_ADVANCE_TRX  CREDIT_LIMIT  INSTALLMENTS_PURCHASES  \
# 0             0.000000      6.908755                4.568506
# 1             1.609438      8.853808                0.000000
# 2             0.000000      8.922792                0.000000
# 3             0.693147      8.922792                0.000000
# 4             0.000000      7.090910                0.000000
# ...                ...           ...                     ...
# 8945          0.000000      6.908755                5.677165
# 8946          0.000000      6.908755                5.707110
# 8947          0.000000      6.908755                4.979489
# 8948          1.098612      6.216606                0.000000
# 8949          1.098612      7.090910                0.000000
#
#       MINIMUM_PAYMENTS  ONEOFF_PURCHASES  ONEOFF_PURCHASES_FREQUENCY  ...  \
# 0             4.945277          0.000000                    0.000000  ...
# 1             6.978531          0.000000                    0.000000  ...
# 2             6.442994          6.651791                    0.693147  ...
# 3             6.762968          7.313220                    0.080042  ...
# 4             5.504483          2.833213                    0.080042  ...
# ...                ...               ...                         ...  ...
# 8945          3.909748          0.000000                    0.000000  ...
# 8946          6.762968          0.000000                    0.000000  ...
# 8947          4.423869          0.000000                    0.000000  ...
# 8948          4.038755          0.000000                    0.000000  ...
# 8949          4.491878          6.997824                    0.510826  ...
#
#       PRC_FULL_PAYMENT  PURCHASES  PURCHASES_FREQUENCY  \
# 0             0.000000   4.568506             0.154151
# 1             0.200671   0.000000             0.000000
# 2             0.000000   6.651791             0.693147
# 3             0.000000   7.313220             0.080042
# 4             0.000000   2.833213             0.080042
# ...                ...        ...                  ...
# 8945          0.405465   5.677165             0.693147
# 8946          0.000000   5.707110             0.693147
# 8947          0.223144   4.979489             0.606136
# 8948          0.223144   0.000000             0.000000
# 8949          0.000000   6.997824             0.510826
#
#       PURCHASES_INSTALLMENTS_FREQUENCY  PURCHASES_TRX    TENURE  \
# 0                             0.080042       1.098612  2.564949
# 1                             0.000000       0.000000  2.564949
# 2                             0.000000       2.564949  2.564949
# 3                             0.000000       0.693147  2.564949
# 4                             0.000000       0.693147  2.564949
# ...                                ...            ...       ...
# 8945                          0.606136       1.945910  1.945910
# 8946                          0.606136       1.945910  1.945910
# 8947                          0.510826       1.791759  1.945910
# 8948                          0.000000       0.000000  1.945910
# 8949                          0.000000       3.178054  1.945910
#
#       limit_usage_ratatio  min_payment_ratio  monthly_avg_purchases  \
# 0                0.040086           0.894662               2.191654
# 1                0.376719           1.574068               0.000000
# 2                0.287197           0.688979               4.180994
# 3                0.200671           0.000000               4.835620
# 4                0.519644           1.327360               0.847298
# ...                   ...                ...                    ...
# 8945             0.028095           2.036042               3.902377
# 8946             0.019002           0.277031               3.931826
# 8947             0.023129           0.686161               3.221539
# 8948             0.026559           0.663978               0.000000
# 8949             0.270477           0.539669               5.210624
#
#       monthly_cash_advance
# 0                 0.000000
# 1                 6.287695
# 2                 0.000000
# 3                 2.898616
# 4                 0.000000
# ...                    ...
# 8945              0.000000
# 8946              0.000000
# 8947              0.000000
# 8948              1.959127
# 8949              3.098890
#
# [8950 rows x 21 columns]

# %%
cr_log=pd.concat([cr_log ,credit.loc[:,['both_one_ins','installment_withou_one','none_one_ins','one_off']]],axis=1)

# %%
import seaborn as sns 
sns.heatmap(cr_log.corr())

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
cr_scaled=sc.fit_transform(cr_log)

# %%
cr_scaled
# Out:
# array([[-1.20521818, -0.14875746, -0.93073294, ...,  1.72051649,
#         -0.54369045, -0.514625  ],
#        [ 0.94891762,  0.17961568,  1.52878819, ..., -0.58122082,
#          1.83928189, -0.514625  ],
#        [ 0.82499258,  0.49271003, -0.93073294, ..., -0.58122082,
#         -0.54369045,  1.94316249],
#        ...,
#        [-1.4738341 , -0.09290575, -0.93073294, ...,  1.72051649,
#         -0.54369045, -0.514625  ],
#        [-1.73377525, -0.09290575,  0.08603831, ..., -0.58122082,
#          1.83928189, -0.514625  ],
#        [-0.11830096, -0.73437135,  0.42995349, ..., -0.58122082,
#         -0.54369045,  1.94316249]])

# %%
from sklearn.decomposition import PCA

# %%
var_ratio={}
for i in range(2,26):
    pc=PCA(n_components = i)
    cr_pca=pc.fit(cr_scaled)
    var_ratio[i]=sum(cr_pca.explained_variance_ratio_)

# %%
var_ratio
# Out:
# {2: 0.5285032469306616,
#  3: 0.6368859221990578,
#  4: 0.7208236615446861,
#  5: 0.7751698120097249,
#  6: 0.8235139586697977,
#  7: 0.8642619839438703,
#  8: 0.8952185517471025,
#  9: 0.9205977691031354,
#  10: 0.9412777193271858,
#  11: 0.9561258246224528,
#  12: 0.9661150698087944,
#  13: 0.9747037127009288,
#  14: 0.9815021181321352,
#  15: 0.9867633329816727,
#  16: 0.9903073086740678,
#  17: 0.992973570012939,
#  18: 0.9948824990386006,
#  19: 0.9966224479739909,
#  20: 0.9983368810579596,
#  21: 0.9994603617928872,
#  22: 0.9997215195039323,
#  23: 0.9999666293820363,
#  24: 0.9999999999999998,
#  25: 0.9999999999999998}

# %%
pd.Series(var_ratio).plot()

# %%
pc_final=PCA(n_components = 9).fit(cr_scaled)

# %%
pc_final
# Out:
# PCA(n_components=9)

# %%
pc_final.explained_variance_
# Out:
# array([8.48698511, 4.72707249, 2.70986966, 2.09867797, 1.35880558,
#        1.20873872, 1.01881447, 0.77400068, 0.63455133])

# %%
pc_final.explained_variance_.sum()
# Out:
# 23.01751601706525

# %%
cr_reduced=pc_final.fit_transform(cr_scaled)

# %%
dd=pd.DataFrame(cr_reduced)

# %%
dd
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.225606 -3.361888 -0.859278 -0.881257 -0.152581 -0.235840  0.073323
# 1    -4.497135  0.740006 -0.162801  1.736986 -1.306137 -0.508172 -0.312046
# 2     1.440968  1.141236  2.735377 -2.283795 -0.390269 -0.947020 -0.124068
# 3    -1.072342 -0.443385  2.215807 -3.031340  1.798279  0.115346 -2.499140
# 4    -1.255497 -1.356607  1.795194 -2.003665 -1.103167 -0.717548  1.414714
# ...        ...       ...       ...       ...       ...       ...       ...
# 8945  2.281242 -3.350852 -1.637311  0.888633  2.629677  0.637509  3.085442
# 8946  1.551327 -2.505018 -2.399246 -1.415214  2.740167  0.935566  1.717320
# 8947  1.462775 -3.696080 -1.692651 -0.471294  2.980648  1.279952  2.046741
# 8948 -3.242988 -3.967156  0.373441  0.584977  2.185476  3.099068  2.548627
# 8949  0.054924  0.057244  2.502896 -1.368240  4.908191  1.376892  1.879565
#
#              7         8
# 0     0.793764  0.127860
# 1    -0.748731 -0.084371
# 2    -1.129249 -0.471075
# 3    -0.565963 -1.175861
# 4     0.613458  0.343373
# ...        ...       ...
# 8945 -2.112707  0.840496
# 8946 -2.255902  1.364906
# 8947 -2.127640  0.766662
# 8948 -1.672024 -0.119282
# 8949 -1.240271  0.435241
#
# [8950 rows x 9 columns]

# %%
pd.DataFrame(pc_final.explained_variance_ratio_ ,index =[' PC _' + str(i) for i in range(0,9)])
# Out:
#                0
#  PC _0  0.339441
#  PC _1  0.189062
#  PC _2  0.108383
#  PC _3  0.083938
#  PC _4  0.054346
#  PC _5  0.048344
#  PC _6  0.040748
#  PC _7  0.030957
#  PC _8  0.025379

# %% [markdown]
# # Clustering

# %%
from sklearn.cluster import KMeans

# %%
KMeans()
# Out:
# KMeans()

# %%
cr_reduced
# Out:
# array([[ 0.22560637, -3.36188787, -0.85927766, ...,  0.07332276,
#          0.79376402,  0.12786031],
#        [-4.49713513,  0.74000558, -0.16280113, ..., -0.3120463 ,
#         -0.74873062, -0.08437145],
#        [ 1.44096751,  1.14123583,  2.73537731, ..., -0.12406845,
#         -1.12924939, -0.47107485],
#        ...,
#        [ 1.46277522, -3.69608013, -1.69265078, ...,  2.04674147,
#         -2.12764042,  0.76666163],
#        [-3.24298833, -3.96715643,  0.37344057, ...,  2.54862726,
#         -1.67202351, -0.11928152],
#        [ 0.05492422,  0.0572436 ,  2.50289589, ...,  1.8795646 ,
#         -1.24027062,  0.43524096]])

# %% [markdown]
# # Cluster error technique for finding n_clusters

# %%
errors=[]
for i in range(1,21):
    clusters=KMeans(i)
    clusters.fit(cr_reduced)
    errors.append(clusters.inertia_)

# %%
errors
# Out:
# [205983.75083683722,
#  147366.54479995836,
#  121478.84625000617,
#  100539.56935072255,
#  87940.64090828194,
#  81192.09781080009,
#  75124.04774862957,
#  70577.82958271897,
#  66613.04899504704,
#  63409.31343601086,
#  60849.31422107072,
#  58100.87484072171,
#  56340.45834641372,
#  54144.2197556876,
#  51534.46677345618,
#  49711.23736252956,
#  47841.37937541265,
#  46729.23038448532,
#  44773.45844831714,
#  43864.59123640944]

# %%
cluster_df =pd.DataFrame({'Cluster_no':np.arange(1,21),'Cluster_errors': errors})

# %%
plt.figure(figsize=(10,10))
plt.plot(cluster_df.Cluster_no,cluster_df.Cluster_errors,marker='o')

# %%
import sklearn

# %%
score=[]
for i in range(2,21):
    km=KMeans(i)
    km.fit(cr_reduced)
    score.append(sklearn.metrics.silhouette_score(cr_reduced,km.labels_))

# %%
score
# Out:
# [0.28525536127898193,
#  0.26385817528636035,
#  0.3125610964105073,
#  0.3109619959964035,
#  0.3063303064777654,
#  0.30671556436643677,
#  0.3063592727718974,
#  0.2740692274217899,
#  0.2708463941511036,
#  0.26379070785295544,
#  0.26607317310942347,
#  0.2558084930638034,
#  0.2612842096136859,
#  0.2531228692577176,
#  0.2472337506973125,
#  0.24536535875841814,
#  0.24813534375620852,
#  0.24802153277459732,
#  0.24572263418951962]

# %%
pd.Series(score).plot()

# %%
km=KMeans(n_clusters=4,random_state=123)

# %%
km.fit(cr_reduced)
# Out:
# KMeans(n_clusters=4, random_state=123)

# %%
km.labels_
# Out:
# array([0, 2, 1, ..., 0, 2, 1])

# %%
pd.Series(km.labels_).value_counts()
# Out:
# 3    2715
# 0    2225
# 2    2150
# 1    1860
# dtype: int64

# %%
credit['clusters']=pd.Series(km.labels_)

# %%
credit
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  ...  TENURE  monthly_avg_purchases  \
# 0                   0.000000  ...      12               7.950000
# 1                   0.250000  ...      12               0.000000
# 2                   0.000000  ...      12              64.430833
# 3                   0.083333  ...      12             124.916667
# 4                   0.000000  ...      12               1.333333
# ...                      ...  ...     ...                    ...
# 8945                0.000000  ...       6              48.520000
# 8946                0.000000  ...       6              50.000000
# 8947                0.000000  ...       6              24.066667
# 8948                0.166667  ...       6               0.000000
# 8949                0.333333  ...       6             182.208333
#
#       monthly_cash_advance  both_one_ins  installment_withou_one  \
# 0                 0.000000             0                       1
# 1               536.912124             0                       0
# 2                 0.000000             0                       0
# 3                17.149001             0                       0
# 4                 0.000000             0                       0
# ...                    ...           ...                     ...
# 8945              0.000000             0                       1
# 8946              0.000000             0                       1
# 8947              0.000000             0                       1
# 8948              6.093130             0                       0
# 8949             21.173335             0                       0
#
#       none_one_ins  one_off  limit_usage_ratatio  min_payment_ratio  clusters
# 0                0        0             0.040901           1.446508         0
# 1                1        0             0.457495           3.826241         2
# 2                0        1             0.332687           0.991682         1
# 3                0        1             0.222223           0.000000         1
# 4                0        1             0.681429           2.771075         1
# ...            ...      ...                  ...                ...       ...
# 8945             0        0             0.028494           6.660231         0
# 8946             0        0             0.019183           0.319208         0
# 8947             0        0             0.023399           0.986076         0
# 8948             1        0             0.026915           0.942505         2
# 8949             0        1             0.310590           0.715439         1
#
# [8950 rows x 26 columns]

# %%
credit.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE', 'monthly_avg_purchases', 'monthly_cash_advance',
#        'both_one_ins', 'installment_withou_one', 'none_one_ins', 'one_off',
#        'limit_usage_ratatio', 'min_payment_ratio', 'clusters'],
#       dtype='object')

# %%
col_kpi=['BALANCE','PURCHASES','monthly_avg_purchases','monthly_cash_advance','limit_usage_ratatio','min_payment_ratio']

# %%
cluster_df_4=pd.concat([credit[col_kpi],pd.Series(km.labels_,name='Clusters')],axis=1)

# %%
cluster_4=cluster_df_4.groupby('Clusters').apply(lambda x: x[col_kpi].mean())
cluster_4
# Out:
#               BALANCE    PURCHASES  monthly_avg_purchases  \
# Clusters
# 0          627.258999   532.179771              46.643789
# 1         1414.646113   781.505839              69.308794
# 2         2240.222290     5.866121               0.514911
# 3         1900.065835  2330.891436             197.960939
#
#           monthly_cash_advance  limit_usage_ratatio  min_payment_ratio
# Clusters
# 0                    21.297819             0.243291          13.387034
# 1                    76.294772             0.377507           5.486977
# 2                   190.635633             0.579121           9.718803
# 3                    72.629989             0.365345           7.361299

# %%
# %matplotlib inline
plt.figure(figsize=(100,100))
cluster_4.plot(kind='bar')
plt.legend()
